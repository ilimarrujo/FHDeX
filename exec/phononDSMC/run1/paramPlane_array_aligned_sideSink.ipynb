# %%
import math;
import numpy as np;
# Import statements
import yt ; yt.funcs.mylog.setLevel(50)
import scipy.constants as scc

# %% [markdown]
# ### initialize plane parameters and domain sizes

# %%
paramPlaneList = [];
originList = [];

d = 315.e-7; # diameter of cylinder
radius = d/2; # 200nm in cgs
a_period  = 373.0e-7; # period of array
w_Al = 8.0e-4; # width of aluminum pad
#add a lenth for the y
w_margin = 0.5e-4; # margin size of Al around the aluminum pad 
height = 100.e-7; # this needs to be consistant with the input file. 
temp = .020; # temperature in K

nx0_elem = 1; nx1_elem = 11; dnx_elem = 1 # starting cylinder element index n0; ending n1-1; interval dn
ny0_elem = 1; ny1_elem = 21; dny_elem = 1

# domain size in cgs
widthX = w_Al + w_margin * 2 + a_period*(nx1_elem-2) * 2 + d*2 + (a_period-d); 
widthY = a_period*(ny1_elem-2) + d + (a_period-d);

#number of surfaces
noOfParamPlanes = 14; # number of rectangles which make a cylinder
theta = 0.0;
delt = 2.0*math.pi/noOfParamPlanes; # 2*pi/# of rectangles

print(widthX/2)
print(widthY/2)
# Out:
# 0.0008201
# 0.00037299999999999996

# %% [markdown]
# ### Define domain boundaries

# %%
###LEFT###
#walls (domain boundaries, need to define as the first param in paramPlanes)
#porosity, surface roughness, temperature, record particles (left and right) (1 for recording)
pl=0.0; sl=2e-7; tl=temp;cl=1.0;
pr=0.0; sr=2e-7; tr=temp;cr=0.0;
# pl=pr=1 - allow to escapse
#periodic
p=0.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
#source
sourcer=0.0;sourcel=0.0;
#area (only used if a source)

#sink
sinkl=1.0;
sinkr=0.0;


###LEFT###
x0= -widthX/2;
y0= -widthY/2;
z0= 0; 

x1= -widthX/2;
y1= widthY/2;
z1= 0; 

x2= -widthX/2;
y2= -widthY/2;
z2= height; 


#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];
#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=v[2];
#surface normals
ln=[1.0,0.0,0.0]; # left is pointing into domain
lnx=ln[0]; lny=ln[1]; lnz=ln[2];
rnx=-lnx; rny=-lny; rnz=-lnz; # right is pointing outward
a=uTop*vTop;
#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
paramPlaneList.append(paramPlane);

# %%
###RIGHT###
#walls (domain boundaries, need to define as the first param in paramPlanes)
#porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
pl=0.0; sl=2e-7; tl=temp;cl=0.0;
pr=0.0; sr=2e-7; tr=temp;cr=1.0;
# pl=pr=1 - allow to escapse
#periodic
p=0.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
#source
sourcer=0.0;sourcel=0.0;
#area (only used if a source)

#sink
sinkl=0.0;
sinkr=1.0;

###RIGHT###
x0= widthX/2;
y0= -widthY/2;
z0= 0; 

x1= widthX/2;
y1= widthY/2;
z1= 0; 

x2= widthX/2;
y2= -widthY/2;
z2= height; 

#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];
#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=v[2];
#surface normals
ln=[1.0,0.0,0.0]; # left is pointing outward the domain
lnx=ln[0]; lny=ln[1]; lnz=ln[2];
rnx=-lnx; rny=-lny; rnz=-lnz; # right is pointing into the domain
a=uTop*vTop;
#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
paramPlaneList.append(paramPlane);

# %%
###BACK###
#walls (domain boundaries, need to define as the first param in paramPlanes)
#porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
pl=0.0; sl=2e-7; tl=temp;cl=0.0;
pr=0.0; sr=2e-7; tr=temp;cr=0.0;
# pl=pr=1 - allow to escapse
#periodic
p=1.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
#source
sourcer=0.0;sourcel=0.0;
#area (only used if a source)

#sink
sinkl=0.0;
sinkr=0.0;

###BACK###
x0= -widthX/2;
y0= -widthY/2;
z0= 0; 

x1= widthX/2;
y1= -widthY/2;
z1= 0; 

x2= -widthX/2;
y2= -widthY/2;
z2= height; 

#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];
#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=v[2];
#surface normals
ln=[0.0,1.0,0.0];
lnx=ln[0]; lny=ln[1]; lnz=ln[2];
rnx=-lnx; rny=-lny; rnz=-lnz;
a=uTop*vTop;
#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
paramPlaneList.append(paramPlane);

# %%
###FRONT###
#walls (domain boundaries, need to define as the first param in paramPlanes)
#porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
pl=0.0; sl=2e-7; tl=temp;cl=0.0;
pr=0.0; sr=2e-7; tr=temp;cr=0.0;
# pl=pr=1 - allow to escapse
#periodic
p=1.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
#source
sourcer=0.0;sourcel=0.0;
#area (only used if a source)

#sink
sinkl=0.0;
sinkr=0.0;

###FRONT###
x0= -widthX/2;
y0= widthY/2;
z0= 0; 

x1= widthX/2;
y1= widthY/2;
z1= 0; 

x2= -widthX/2;
y2= widthY/2;
z2= height; 

#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];
#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=v[2];
#surface normals
ln=[0.0,1.0,0.0];
lnx=ln[0]; lny=ln[1]; lnz=ln[2];
rnx=-lnx; rny=-lny; rnz=-lnz;
a=uTop*vTop;
#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
paramPlaneList.append(paramPlane);

# %%
###BOTTOM###
#walls (domain boundaries, need to define as the first param in paramPlanes)
#porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
pl=0.0; sl=2e-7; tl=temp;cl=0.0;
pr=0.0; sr=2e-7; tr=temp;cr=0.0;
# pl=pr=1 - allow to escapse
#periodic
p=0.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
#source
sourcer=0.0;sourcel=0.0;
#area (only used if a source)

#sink
sinkl=0.0;
sinkr=0.0;

###BOTTOM###
x0= -widthX/2;
y0= -widthY/2;
z0= 0; 

x1= -widthX/2;
y1= widthY/2;
z1= 0; 

x2= widthX/2;
y2= -widthY/2;
z2= 0; 

#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];
#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=v[2];
#surface normals
ln=[0.0,0.0,1.0];
lnx=ln[0]; lny=ln[1]; lnz=ln[2];
rnx=-lnx; rny=-lny; rnz=-lnz;
a=uTop*vTop;
#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
paramPlaneList.append(paramPlane);

# %%
###TOP###
#walls (domain boundaries, need to define as the first param in paramPlanes)
#porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
pl=0.0; sl=2e-7; tl=temp;cl=0.0;
pr=0.0; sr=2e-7; tr=temp;cr=0.0;
# pl=pr=1 - allow to escapse
#periodic
p=0.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
#source
sourcer=0.0;sourcel=0.0;
#area (only used if a source)

#sink
sinkl=0.0;
sinkr=0.0;

###TOP###
x0= -widthX/2;
y0= -widthY/2;
z0= height; 

x1= -widthX/2;
y1= widthY/2;
z1= height; 

x2= widthX/2;
y2= -widthY/2;
z2= height; 

#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];
#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=v[2];
#surface normals
ln=[0.0,0.0,1.0];
lnx=ln[0]; lny=ln[1]; lnz=ln[2];
rnx=-lnx; rny=-lny; rnz=-lnz;
a=uTop*vTop;
#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
paramPlaneList.append(paramPlane);

# %%
##change the geometry of the setup 
# right array
a_positionx1 = w_Al/2 + w_margin + radius; # 2um Al pad with 1um margin

for iteration_x in range (nx0_elem, nx1_elem, dnx_elem) : # count of cynlinders in x 
    offsetx = a_positionx1 + a_period * (iteration_x-1)*1.17; # keep in mind range() function does not include upper #
    for iteration_y in range (ny0_elem, ny1_elem, dny_elem) :
        offsety = - a_period * (ny1_elem - 2) / 2 + (iteration_y - 1) * a_period; # odd & even both valid
        offsetz = 0; 
        offset = [offsetx,offsety,offsetz]; # in centimeter; in cgs; if wanted to switch to SI, change the value of k_B in input file
        print(iteration_x, iteration_y);
        print(offsetx,offsety);
        
        #making a cylinder out of 40 rectangles
        for ii in range(noOfParamPlanes):
            #define parametric surface
            x0=math.cos(ii*delt)*radius+offset[0]; # origin of vector
            y0=math.sin(ii*delt)*radius+offset[1];
            z0 = 0.0; 
            
            x1=math.cos((ii+1)*delt)*radius+offset[0];
            y1=math.sin((ii+1)*delt)*radius+offset[1];
            z1=0.0;
            
            #tangent and parameter 1
            # utop and vtop tell the span of these two vectors to form a plane
            uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2) # difference between x and y projections
            u=[x1-x0,y1-y0,z1-z0]/uTop; # normalize
            ux=u[0]; uy=u[1]; uz=u[2]; # vector tangential to cylinder surface and in the xy plane
            
            #tangent and parameter 2
            vx=0.0; vy=0.0; vz=1.0; # vector tangential to cylinder surface and in the z direction
            vTop = height;
            
            #surface normals
            xt=math.cos((ii+0.5)*delt)*radius+offset[0];
            yt=math.sin((ii+0.5)*delt)*radius+offset[1];
            zt=height/2;
            ln=[offset[0]-xt,offset[1]-yt,height/2-zt]/np.linalg.norm([offset[0]-xt,offset[1]-yt,height/2-zt],2);
            lnx=ln[0]; lny=ln[1]; lnz=ln[2];
            rnx=-lnx; rny=-lny; rnz=-lnz;
            # vector normal to the rectangle segment; right and left are pointing to different directions as of the surface
            # rn = [math.cos((ii+0.5)*delt)*radius, math.sin((ii+0.5)*delt)*radius, 0]/np.linalg.norm([math.cos((ii+0.5)*delt)*radius, math.sin((ii+0.5)*delt)*radius, 0],2);

            #porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
            pl=0.0; sl=2.0e-7; tl=temp;cl=0.0;
            pr=0.0; sr=2.0e-7; tr=temp;cr=0.0;
            
            #periodic
            p=0.0;
            
            # since the cylinder segments are not source, these are set to be ineffective
            # 2 species of particles for now; can change freely
            #density if a source, for each species (left and right)
            nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
            #source
            sourcer=0.0;sourcel=0.0;
            #area (only used if a source)
            a=0.0;
            #sink
            sinkl=0.0;
            sinkr=0.0;
            
            #code expects it in this order:
            paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
            paramPlaneList.append(paramPlane);
            
print("array = ",np.shape(paramPlaneList))
print("element = ",np.shape(paramPlane))
# Out:
# 1 1
# 0.00046575 -0.00035434999999999997
# 1 2
# 0.00046575 -0.00031705
# 1 3
# 0.00046575 -0.00027974999999999994
# 1 4
# 0.00046575 -0.00024244999999999996
# 1 5
# 0.00046575 -0.00020514999999999997
# 1 6
# 0.00046575 -0.00016785
# 1 7
# 0.00046575 -0.00013054999999999997
# 1 8
# 0.00046575 -9.324999999999996e-05
# 1 9
# 0.00046575 -5.594999999999998e-05
# 1 10
# 0.00046575 -1.8649999999999993e-05
# 1 11
# 0.00046575 1.8649999999999993e-05
# 1 12
# 0.00046575 5.595000000000003e-05
# 1 13
# 0.00046575 9.325000000000002e-05
# 1 14
# 0.00046575 0.00013055
# 1 15
# 0.00046575 0.00016785000000000004
# 1 16
# 0.00046575 0.00020515000000000003
# 1 17
# 0.00046575 0.00024245
# 1 18
# 0.00046575 0.00027975
# 1 19
# 0.00046575 0.00031705
# 1 20
# 0.00046575 0.00035434999999999997
# 2 1
# 0.000509391 -0.00035434999999999997
# 2 2
# 0.000509391 -0.00031705
# 2 3
# 0.000509391 -0.00027974999999999994
# 2 4
# 0.000509391 -0.00024244999999999996
# 2 5
# 0.000509391 -0.00020514999999999997
# 2 6
# 0.000509391 -0.00016785
# 2 7
# 0.000509391 -0.00013054999999999997
# 2 8
# 0.000509391 -9.324999999999996e-05
# 2 9
# 0.000509391 -5.594999999999998e-05
# 2 10
# 0.000509391 -1.8649999999999993e-05
# 2 11
# 0.000509391 1.8649999999999993e-05
# 2 12
# 0.000509391 5.595000000000003e-05
# 2 13
# 9 1
# 0.000814878 -0.00035434999999999997
# 9 2
# 0.000814878 -0.00031705
# 9 3
# 0.000814878 -0.00027974999999999994
# 9 4
# 0.000814878 -0.00024244999999999996
# 9 5
# 0.000814878 -0.00020514999999999997
# 9 6
# 0.000814878 -0.00016785
# 9 7
# 0.000814878 -0.00013054999999999997
# 9 8
# 0.000814878 -9.324999999999996e-05
# 9 9
# 0.000814878 -5.594999999999998e-05
# 9 10
# 0.000814878 -1.8649999999999993e-05
# 9 11
# 0.000814878 1.8649999999999993e-05
# 9 12
# 0.000814878 5.595000000000003e-05
# 9 13
# 0.000814878 9.325000000000002e-05
# 9 14
# 0.000814878 0.00013055
# 9 15
# 0.000814878 0.00016785000000000004
# 9 16
# 0.000814878 0.00020515000000000003
# 9 17
# 0.000814878 0.00024245
# 9 18
# 0.000814878 0.00027975
# 9 19
# 0.000814878 0.00031705
# 9 20
# 0.000814878 0.00035434999999999997
# 10 1
# 0.000858519 -0.00035434999999999997
# 10 2
# 0.000858519 -0.00031705
# 10 3
# 0.000858519 -0.00027974999999999994
# 10 4
# 0.000858519 -0.00024244999999999996
# 10 5
# 0.000858519 -0.00020514999999999997
# 10 6
# 0.000858519 -0.00016785
# 10 7
# 0.000858519 -0.00013054999999999997
# 10 8
# 0.000858519 -9.324999999999996e-05
# 10 9
# 0.000858519 -5.594999999999998e-05
# 10 10
# 0.000858519 -1.8649999999999993e-05
# 10 11
# 0.000858519 1.8649999999999993e-05
# 10 12
# 0.000858519 5.595000000000003e-05
# 10 13
# 0.000858519 9.325000000000002e-05
# 10 14
# 0.000858519 0.00013055
# 10 15
# 0.000858519 0.00016785000000000004
# 10 16
# 0.000858519 0.00020515000000000003
# 10 17
# 0.000858519 0.00024245
# 10 18
# 0.000858519 0.00027975
# 10 19
# 0.000858519 0.00031705
# 10 20
# 0.000858519 0.00035434999999999997
# array =  (2806, 35)
# element =  (35,)

# %%
# left array
a_positionx2 = - w_Al/2 - w_margin - radius; # 2um Al pad with 1um margin
for iteration_x in range (nx0_elem, nx1_elem, dnx_elem) : # count of cynlinders in x 
    offsetx = a_positionx2 - a_period * (iteration_x-1)*1.17; # keep in mind range() function does not include upper #
    for iteration_y in range (ny0_elem, ny1_elem, dny_elem) :
        offsety = - a_period * (ny1_elem - 2) / 2 + (iteration_y - 1) * a_period; # odd & even both valid
        offsetz = 0; 
        offset = [offsetx,offsety,offsetz]; # in centimeter; in cgs; if wanted to switch to SI, change the value of k_B in input file
        print(iteration_x, iteration_y);
        print(offsetx,offsety);
        
        #making a cylinder out of 40 rectangles
        for ii in range(noOfParamPlanes):
            #define parametric surface
            x0=math.cos(ii*delt)*radius+offset[0]; # origin of vector
            y0=math.sin(ii*delt)*radius+offset[1];
            z0 = 0.0; 
            
            x1=math.cos((ii+1)*delt)*radius+offset[0];
            y1=math.sin((ii+1)*delt)*radius+offset[1];
            z1=0.0;
            
            #tangent and parameter 1
            # utop and vtop tell the span of these two vectors to form a plane
            uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2) # difference between x and y projections
            u=[x1-x0,y1-y0,z1-z0]/uTop; # normalize
            ux=u[0]; uy=u[1]; uz=u[2]; # vector tangential to cylinder surface and in the xy plane
            
            #tangent and parameter 2
            vx=0.0; vy=0.0; vz=1.0; # vector tangential to cylinder surface and in the z direction
            vTop = height;
            
            #surface normals
            xt=math.cos((ii+0.5)*delt)*radius+offset[0];
            yt=math.sin((ii+0.5)*delt)*radius+offset[1];
            zt=height/2;
            ln=[offset[0]-xt,offset[1]-yt,height/2-zt]/np.linalg.norm([offset[0]-xt,offset[1]-yt,height/2-zt],2);
            lnx=ln[0]; lny=ln[1]; lnz=ln[2];
            rnx=-lnx; rny=-lny; rnz=-lnz;
            # vector normal to the rectangle segment; right and left are pointing to different directions as of the surface
            # rn = [math.cos((ii+0.5)*delt)*radius, math.sin((ii+0.5)*delt)*radius, 0]/np.linalg.norm([math.cos((ii+0.5)*delt)*radius, math.sin((ii+0.5)*delt)*radius, 0],2);

            #porosity, specularity (surface roughness), temperature, record particles (left and right) (1 for recording)
            pl=0.0; sl=2e-7; tl=temp;cl=0.0;
            pr=0.0; sr=2e-7; tr=temp;cr=0.0;
            
            #periodic
            p=0.0;
            
            # since the cylinder segments are not source, these are set to be ineffective
            # 2 species of particles for now; can change freely
            #density if a source, for each species (left and right)
            nr0=0.0; nr1=0.0;nl0=0.0;nl1=0.0;
            #source
            sourcer=0.0;sourcel=0.0;
            #area (only used if a source)
            a=0.0;
            #sink
            sinkl=0.0;
            sinkr=0.0;
            
            #code expects it in this order:
            paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];
            paramPlaneList.append(paramPlane);
# Out:
# 1 1
# -0.00046575 -0.00035434999999999997
# 1 2
# -0.00046575 -0.00031705
# 1 3
# -0.00046575 -0.00027974999999999994
# 1 4
# -0.00046575 -0.00024244999999999996
# 1 5
# -0.00046575 -0.00020514999999999997
# 1 6
# -0.00046575 -0.00016785
# 1 7
# -0.00046575 -0.00013054999999999997
# 1 8
# -0.00046575 -9.324999999999996e-05
# 1 9
# -0.00046575 -5.594999999999998e-05
# 1 10
# -0.00046575 -1.8649999999999993e-05
# 1 11
# -0.00046575 1.8649999999999993e-05
# 1 12
# -0.00046575 5.595000000000003e-05
# 1 13
# -0.00046575 9.325000000000002e-05
# 1 14
# -0.00046575 0.00013055
# 1 15
# -0.00046575 0.00016785000000000004
# 1 16
# -0.00046575 0.00020515000000000003
# 1 17
# -0.00046575 0.00024245
# 1 18
# -0.00046575 0.00027975
# 1 19
# -0.00046575 0.00031705
# 1 20
# -0.00046575 0.00035434999999999997
# 2 1
# -0.000509391 -0.00035434999999999997
# 2 2
# -0.000509391 -0.00031705
# 2 3
# -0.000509391 -0.00027974999999999994
# 2 4
# -0.000509391 -0.00024244999999999996
# 2 5
# -0.000509391 -0.00020514999999999997
# 2 6
# -0.000509391 -0.00016785
# -0.000771237 9.325000000000002e-05
# 8 14
# -0.000771237 0.00013055
# 8 15
# -0.000771237 0.00016785000000000004
# 8 16
# -0.000771237 0.00020515000000000003
# 8 17
# -0.000771237 0.00024245
# 8 18
# -0.000771237 0.00027975
# 8 19
# -0.000771237 0.00031705
# 8 20
# -0.000771237 0.00035434999999999997
# 9 1
# -0.000814878 -0.00035434999999999997
# 9 2
# -0.000814878 -0.00031705
# 9 3
# -0.000814878 -0.00027974999999999994
# 9 4
# -0.000814878 -0.00024244999999999996
# 9 5
# -0.000814878 -0.00020514999999999997
# 9 6
# -0.000814878 -0.00016785
# 9 7
# -0.000814878 -0.00013054999999999997
# 9 8
# -0.000814878 -9.324999999999996e-05
# 9 9
# -0.000814878 -5.594999999999998e-05
# 9 10
# -0.000814878 -1.8649999999999993e-05
# 9 11
# -0.000814878 1.8649999999999993e-05
# 9 12
# -0.000814878 5.595000000000003e-05
# 9 13
# -0.000814878 9.325000000000002e-05
# 9 14
# -0.000814878 0.00013055
# 9 15
# -0.000814878 0.00016785000000000004
# 9 16
# -0.000814878 0.00020515000000000003
# 9 17
# -0.000814878 0.00024245
# 9 18
# -0.000814878 0.00027975
# 9 19
# -0.000814878 0.00031705
# 9 20
# -0.000814878 0.00035434999999999997
# 10 1
# -0.000858519 -0.00035434999999999997
# 10 2
# -0.000858519 -0.00031705
# 10 3
# -0.000858519 -0.00027974999999999994
# 10 4
# -0.000858519 -0.00024244999999999996
# 10 5
# -0.000858519 -0.00020514999999999997
# 10 6
# -0.000858519 -0.00016785
# 10 7
# -0.000858519 -0.00013054999999999997
# 10 8
# -0.000858519 -9.324999999999996e-05
# 10 9
# -0.000858519 -5.594999999999998e-05
# 10 10
# -0.000858519 -1.8649999999999993e-05
# 10 11
# -0.000858519 1.8649999999999993e-05
# 10 12
# -0.000858519 5.595000000000003e-05
# 10 13
# -0.000858519 9.325000000000002e-05
# 10 14
# -0.000858519 0.00013055
# 10 15
# -0.000858519 0.00016785000000000004
# 10 16
# -0.000858519 0.00020515000000000003
# 10 17
# -0.000858519 0.00024245
# 10 18
# -0.000858519 0.00027975
# 10 19
# -0.000858519 0.00031705
# 10 20
# -0.000858519 0.00035434999999999997

# %%
#rectangle to act as source:

x0= -w_Al/2; # -2um as in the paper, in cm unit
y0= -w_Al/2;
z0 = height - 0.0000000001; 

x1= w_Al/2;
y1= -w_Al/2;
z1= height - 0.0000000001; 

x2= -w_Al/2;
y2= w_Al/2;
z2= height - 0.0000000001; 

#tangent and parameter 1
uTop = np.linalg.norm([x1-x0,y1-y0,z1-z0],2)
u=[x1-x0,y1-y0,z1-z0]/uTop;
ux=u[0]; uy=u[1]; uz=u[2];

#tangent and parameter 2
vTop = np.linalg.norm([x2-x0,y2-y0,z2-z0],2)
v=[x2-x0,y2-y0,z2-z0]/vTop;
vx=v[0]; vy=v[1]; vz=u[2];

#surface normals

ln=[0.0,0.0,-1.0];
lnx=ln[0]; lny=ln[1]; lnz=ln[2]; # left is defined to point into the domain with this setup
rnx=-lnx; rny=-lny; rnz=-lnz;

#porosity, surface roughness, temperature, record particles (left and right)
pl=0.0; sl=2.0e-7; tl=0.25;cl=0.0;
pr=0.0; sr=2.0e-7; tr=0.25;cr=0.0;

#periodic
p=0.0;

#density if a source, for each species (left and right)
nr0=0.0; nr1=0.0;nl0=0.0;nl1=2.0e18;
#source
sourcer=0.0;sourcel=1.0; 
#area (only used if a source)
a=w_Al*w_Al;
#sink
sinkl=0.0;
sinkr=0.0;

#code expects it in this order:
paramPlane=[x0,y0,z0,ux,uy,uz,vx,vy,vz,uTop,vTop,rnx,rny,rnz,lnx,lny,lnz,pr,sr,tr,nr0,nr1,sourcer,sinkr,cr,pl,sl,tl,nl0,nl1,sourcel,sinkl,cl,p,a];

paramPlaneList.append(paramPlane);

# %%
#Plot surfaces

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
n = 20

fig = plt.figure();
fig.set_size_inches(30, 20)
ax = fig.add_subplot(121, projection='3d');
#ax.set_zlim(0,0.012);
#ax.set_xlim(0,0.08);
#ax.set_ylim(0,0.08);
#ax.view_init(36, 26);

totalPlanes = len(paramPlaneList);

for ii in range(totalPlanes):
    u = np.linspace(0, paramPlaneList[ii][9], n) # utop, norm of section length
    v = np.linspace(0, paramPlaneList[ii][10], n) # vtop
    u, v = np.meshgrid(u, v)

    x = paramPlaneList[ii][0] + paramPlaneList[ii][3]*u + paramPlaneList[ii][6]*v; # x0, ux, vx
    y = paramPlaneList[ii][1] + paramPlaneList[ii][4]*u + paramPlaneList[ii][7]*v; # y0, uy, vy
    z = paramPlaneList[ii][2] + paramPlaneList[ii][5]*u + paramPlaneList[ii][8]*v; # z0, uz, vz
    
    surf = ax.plot_surface(x,y,z)
    
#ax.view_init(60, -65)
ax.view_init(90, 90)
plt.show()

# %%
#Plot cut

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
n = 20

plt.rcParams.update({'font.size': 32})
fig = plt.figure();
fig.set_size_inches(60, 22)
#ax.set_zlim(0,0.012);
#ax.set_xlim(0,0.08);
#ax.set_ylim(0,0.08);
#ax.view_init(36, 26);

totalPlanes = len(paramPlaneList);

for ii in range(totalPlanes):
    u = np.linspace(0, paramPlaneList[ii][9], n) # utop, norm of section length
    v = np.linspace(0, paramPlaneList[ii][10], n) # vtop
    u, v = np.meshgrid(u, v)
    
    x = paramPlaneList[ii][0] + paramPlaneList[ii][3]*u + paramPlaneList[ii][6]*v; # x0, ux, vx
    y = paramPlaneList[ii][1] + paramPlaneList[ii][4]*u + paramPlaneList[ii][7]*v; # y0, uy, vy
    z = paramPlaneList[ii][2] + paramPlaneList[ii][5]*u + paramPlaneList[ii][8]*v; # z0, uz, vz
    
    plt.scatter(x, y)

# %%
#write surfaces to file
import os
if os.path.isfile("paramplanes.dat"):
    os.remove("paramplanes.dat");

totalPlanes = len(paramPlaneList);

f = open('paramplanes.dat','a');
f.write('{}'.format(totalPlanes));
f.write('\n');

kk=0;

for ii in range(totalPlanes):
    totalElements = len(paramPlaneList[ii])
    for jj in range(totalElements):
        kk = kk+1;
        f.write('{}'.format(paramPlaneList[ii][jj]));
        f.write('\n');
        
f.close()

# %%
len(paramPlaneList)
# Out:
# 5607
